# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum(np.power((y - yp), 2)) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 187.249
# The Mean absolute error is 10.879

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 我選擇Dataset中的Goodreads-books，因為我喜歡看書，這個分析可以推薦並幫助我知道，下一本書可以看哪一本。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 這組data來自於https://www.goodreads.com/所公布統計，透過Goodreads提供的API獲得他們的統計數據。蒐集方式應該是透過該網站加入的網友，分享它們對書的期待、觀看後的想法與評分，最後獲得的統計數據。
# 3. 蒐集而來的資料型態為何
# 資料的型態以提供富有意義的欄位格式，透過API可指定回傳的欄位資訊。例如：書籍的ISBN、讀者對書的評比分數、顯示作者的id等等
# 4. 這組資料想解決的問題如何評估
# 假設以書籍推薦的可讀性為例，可分客觀評估與主觀評估，客觀評估就是選定幾個欄位，無關於讀者得本身特質，透過特定的幾個欄位來統計分析，並從統計結果來當作該書的好壞，例如：統計看該書的人數、讀者給該書的評比...等等客觀因素來推薦。但是這種推薦方式對讀者反而造成困擾，例如：不是每個讀者都喜歡烹飪的書，卻一直被推薦烹飪的書。因此系統必須透過讀者們的本身喜好，以及讀書習慣，來訓練出一個模型，能夠針對讀者主觀習性，並參考客觀評估，來完成一套書籍推薦系統。而評估方式或許可採用RMSE等得回歸方式，來評估模型的結果是否接近讀者喜好。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 應該透過資料分析去調整既有的叫車與分配乘客系統，讓車隊的車的使用率提升，減少空轉沒有載客，四處繞找客戶的時間。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 若要透過資料分析系統勢必要蒐集資料，資料的蒐集可透過主動與被動的方式蒐集，主動的方式為公司設計App提供司機與遊客使用，當客戶叫車時會回報叫車資訊給系統端，而司機載客後也可回報載客資訊。被動的方式則是，系統可透過載客資訊與Google map資訊進行整合分析，以進行開車路徑等等的優化。
# 3. 蒐集而來的資料型態為何
# 可用整數表示的資料，例如：基本的客戶資料、性別、年齡、使用次數、上車及下車的GPS位置；另外一些可用字串存上、下車地址或使用時間來表示上、下車時間、載客時間、空等時間等相關資訊。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 假設實際車子被使用率也達八成，系統評估車子載客率可達八成，可視為True positive；
# 而實際車子被使用率未達八成，系統評估車子載客率已達八成，視為False positive;
# 而實際車子被使用率未達八成，系統評估車子載客率也未達八成，視為True negative;
# 而實際車子被使用率已達八成，系統評估車子載客率也未達八成，視為False negative;
# 再依此種分類來計算系統的Accuracy。
